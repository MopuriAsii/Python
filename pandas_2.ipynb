# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Name": ["emp_" + str(i) for i in range(100)],
    "city": np.random.choice(["kkd", "HYD", "Chennai", "Pune"], size=100),
    "salary": np.random.randint(1000, 100000, size=100),
    "Age": np.random.randint(20, 50, size=100),
}
# print(data)
df = pd.DataFrame(data)
# Out:
#       Name     city  salary  Age
# 0    emp_0  Chennai   40080   48
# 1    emp_1      kkd   63674   28
# 2    emp_2      HYD   46510   27
# 3    emp_3      kkd   66572   24
# 4    emp_4  Chennai   90697   33
# ..     ...      ...     ...  ...
# 95  emp_95     Pune   60497   37
# 96  emp_96      HYD   58715   46
# 97  emp_97      kkd   33241   45
# 98  emp_98  Chennai   62974   46
# 99  emp_99      HYD   82350   43
#
# [100 rows x 4 columns]

# %%
df.head(10)
# Out:
#     Name     city  salary  Age
# 0  emp_0  Chennai   40080   48
# 1  emp_1      kkd   63674   28
# 2  emp_2      HYD   46510   27
# 3  emp_3      kkd   66572   24
# 4  emp_4  Chennai   90697   33
# 5  emp_5      HYD   41872   31
# 6  emp_6      kkd   39802   49
# 7  emp_7      kkd   30931   30
# 8  emp_8  Chennai   56006   42
# 9  emp_9      kkd   73883   25

# %%
df.tail(10)
# Out:
#       Name     city  salary  Age
# 90  emp_90  Chennai   59941   48
# 91  emp_91     Pune   11164   49
# 92  emp_92  Chennai   90877   47
# 93  emp_93  Chennai    2877   45
# 94  emp_94      kkd   87625   47
# 95  emp_95     Pune   60497   37
# 96  emp_96      HYD   58715   46
# 97  emp_97      kkd   33241   45
# 98  emp_98  Chennai   62974   46
# 99  emp_99      HYD   82350   43

# %%
df.to_csv('employee.csv',index='False')
df.to_json('employee.json',orient='records')

# %%
df_csv=pd.read_csv('employee.csv')
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   Name        100 non-null    object
#  2   city        100 non-null    object
#  3   salary      100 non-null    int64
#  4   Age         100 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 4.0+ KB

# %%
df_csv.head()# gives the first 5 records
df_csv.tail()#gives last 5 reecords
df_csv.describe()#gives the structure
# Out:
#        Unnamed: 0        salary         Age
# count  100.000000    100.000000  100.000000
# mean    49.500000  52525.160000   35.840000
# std     29.011492  29654.641311    8.841728
# min      0.000000   2877.000000   20.000000
# 25%     24.750000  27093.750000   28.000000
# 50%     49.500000  49429.500000   35.000000
# 75%     74.250000  82251.000000   45.000000
# max     99.000000  99952.000000   49.000000

# %%
json1=pd.read_json('employee.json')
#ex1=pd.read_excel('employee.xlsx',sheet_name='sheet1')

# %%
import json
with open('employee.json') as f1:
    data_json=json.load(f1)
df_json=pd.DataFrame(data_json)

# %%
df_json.head()
# Out:
#     Name     city  salary  Age
# 0  emp_0  Chennai   40080   48
# 1  emp_1      kkd   63674   28
# 2  emp_2      HYD   46510   27
# 3  emp_3      kkd   66572   24
# 4  emp_4  Chennai   90697   33

# %%
df_csv[['Name','Age']]
# Out:
#       Name  Age
# 0    emp_0   48
# 1    emp_1   28
# 2    emp_2   27
# 3    emp_3   24
# 4    emp_4   33
# ..     ...  ...
# 95  emp_95   37
# 96  emp_96   46
# 97  emp_97   45
# 98  emp_98   46
# 99  emp_99   43
#
# [100 rows x 2 columns]

# %%
df_json[['Name','Age']].head()
# Out:
#     Name  Age
# 0  emp_0   48
# 1  emp_1   28
# 2  emp_2   27
# 3  emp_3   24
# 4  emp_4   33

# %%
df_ec=pd.read_excel('Customer.xlsx')# to start we need to read excel file
df_ec
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df_ec.head(10)
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
# 5        1006        Ron   Swanson  304-762-2467
# 6        1007       Jeff    Winger           NaN
# 7        1008   Sherlock    Holmes  876|678|3469
# 8        1009    Gandalf       NaN           N/a
# 9        1010      Peter    Parker  123-545-5421
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# ...

# %%
df_ec["Phone_Number"]=df_ec["Phone_Number"].str.replace('N/a','0')
df_ec
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN             0
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df_ec['Phone_Number']=df_ec['Phone_Number'].fillna(0)
df_ec
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White             0
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger             0
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN             0
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee             0
# 11        1012      Harry    ...Potter             0
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df1=df_ec.drop_duplicates()

# %%
df2=df_ec.drop(columns='Not_Useful_Column')
df2
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White             0
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger             0
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN             0
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee             0
# 11        1012      Harry    ...Potter             0
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df2[['street','city','zipCode']]=df2['Address'].str.split(',',n=2,expand=True)
df2
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White             0
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger             0
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN             0
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee             0
# 11        1012      Harry    ...Potter             0
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df3=df2.drop(columns='Address')
df3
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421             Yes
# 1         1002       Abed        Nadir  123/643/9775              No
# 2         1003     Walter       /White             0               N
# 3         1004     Dwight      Schrute  123-543-2345             Yes
# 4         1005        Jon         Snow  876|678|3469               Y
# 5         1006        Ron      Swanson  304-762-2467             Yes
# 6         1007       Jeff       Winger             0              No
# 7         1008   Sherlock       Holmes  876|678|3469               N
# 8         1009    Gandalf          NaN             0             Yes
# 9         1010      Peter       Parker  123-545-5421             Yes
# 10        1011    Samwise       Gamgee             0             Yes
# 11        1012      Harry    ...Potter             0               Y
# 12        1013        Don       Draper  123-543-2345             Yes
# ...
